# %% [markdown]
# Data Preprocessing with NumPy and Pandas

# %% [markdown]
# Explanation:
#
# Creating the NumPy Array: The scores array is created using np.array to hold the student scores.
#
# Calculating Mean Scores: The mean for each subject is calculated using np.mean, with axis=0 to compute the mean across rows (i.e., per subject).
#
# Standardizing Scores: The scores are standardized by subtracting the mean and dividing by the standard deviation, which is calculated using np.std.
#
# Converting to Pandas DataFrame: The standardized scores are converted into a pandas DataFrame with subject names as the column headers.
#
# Output Example:
#
# Running the script will output the mean scores for each subject and display the standardized scores in a DataFrame format.
#
# You can expand this script to include more subjects and students by adding more rows and columns to the scores array and updating the subject_names list accordingly.

# %%
import numpy as np
import pandas as pd

# 1. Create a NumPy array with student scores
scores = np.array([[85, 90, 88], [78, 85, 92], [90, 95, 85]])

# 2. Calculate the mean score for each subject
mean_scores = np.mean(scores, axis=0)
print("Mean scores for each subject:", mean_scores)

# 3. Standardize the scores by subtracting the mean and dividing by the standard deviation for each subject
std_scores = np.std(scores, axis=0)
standardized_scores = (scores - mean_scores) / std_scores

# 4. Convert the standardized scores into a pandas DataFrame and add column names for the subjects
subject_names = ['Math', 'Science', 'English']
df = pd.DataFrame(standardized_scores, columns=subject_names)

print("Standardized Scores DataFrame:")
print(df)
# Out:
# Mean scores for each subject: [84.33333333 90.         88.33333333]
# Standardized Scores DataFrame:
#        Math   Science   English
# 0  0.135457  0.000000 -0.116248
# 1 -1.286842 -1.224745  1.278724
# 2  1.151385  1.224745 -1.162476
